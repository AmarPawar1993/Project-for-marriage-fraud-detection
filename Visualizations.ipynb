# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('dfCat.csv')

# %%
#this is for previous dataset

sns.set_theme(style="darkgrid")




barplot6 = sns.countplot(x="GenderSpouse", data=df) 



barplot9 = sns.countplot(x="MaritalStatusPetitioner", data=df) 





barplot10 = sns.countplot(x="MaritalStatusBeneficiary", data=df) 




barplot11 = sns.countplot(x="PetitionerEthnicity", data=df) 





barplot12 = sns.countplot(x="PetitionerRace", data=df) 




barplot13 = sns.countplot(x="PetitionerCitizenStatus", data=df) 





barplot16 = sns.countplot(x="StayingTogetherStatus", data=df) 





barplot17 = sns.countplot(x="CurrentMaritalStatus", data=df) 




barplot18 = sns.countplot(x="FederalTaxFiled", data=df) 




barplot19 = sns.countplot(x="SameEmployer", data=df) 




barplot20 = sns.countplot(x="ImmigrationProceeding", data=df) 





barplot21 = sns.countplot(x="CriminalityProvedConvicted", data=df)





barplot22 = sns.countplot(x="PreviousPetitionFiledPetitioner", data=df) 





barplot23 = sns.countplot(x="PreviousPetitionFiledSpouse", data=df) 




barplot24 = sns.countplot(x="BeneficiaryInUS", data=df) 




barplot25 = sns.countplot(x="PreparerorLawyerUsed", data=df) 





barplot26 = sns.countplot(x="PetitionerGender", data=df) 





barplot28 = sns.countplot(x="NumberOfMarriagesPetitioner", data=df) 





barplot29 = sns.countplot(x="NumberOfMarriagesBeneficiary", data=df) 




barplot34 = sns.countplot(x="BeneficiaryEthnicity", data=df) 




barplot35 = sns.countplot(x="CriminalityProvedConvictedType", data=df) 





barplot37 = sns.countplot(x="PreviousPetitionRejectionConditionPetitioner", data=df) 



barplot38 = sns.countplot(x="PreviousPetitionRejectionConditionSpouse", data=df)

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)



sns.pairplot(df)

# %%
#previous dataset
c = [ 'orange','red', 'blue', 'black', 'yellow']


pd.cut(df['TotalIncome'],[0,500000,1000000,1500000]).value_counts().plot.bar()

pd.cut(df['RegularIncome'],[0,25000,50000,75000,100000 ]).value_counts().plot.bar()



pd.cut(df['SupplementalIncome'],[0,25000,50000,75000,100000 ]).value_counts().plot.bar()




ax=pd.cut(df['SupplementalIncome'],[0,25000,50000,75000,100000 ]).value_counts().plot.bar(color=c)
ax.set_title("SUPPLEMENTAL INCOME BAR GRAPH")
ax.set_xlabel("SUPPLEMENTAL INCOME")
ax.set_ylabel("COUNT")




ax=pd.cut(df['RegularIncome'],[0,25000,50000,75000,100000 ]).value_counts().plot.bar(color=c)
ax.set_title("REGULAR INCOME BAR GRAPH")
ax.set_xlabel("REGULAR INCOME")
ax.set_ylabel("COUNT")



orderReasons=['Major Reasons', 'Moderate Reasons','Minor Reasons']




barplot037 = sns.countplot(x="PreviousPetitionRejectionConditionPetitioner", data=df,order=orderReasons).set_title('SEVERITY OF REJECTION REASON FOR PETITIONER')





barplot038 = sns.countplot(x="PreviousPetitionRejectionConditionSpouse", data=df,order=orderReasons).set_title('SEVERITY OF REJECTION REASON FOR SPOUSE')





barplot038 = sns.countplot(x="PreviousPetitionRejectionConditionSpouse", data=df,order=orderReasons)

# %%
sns.catplot(x="[I864]RegularIncome", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df).set(title='Title of Plot')
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome ", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[I864]RegularIncome", y="DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-0963aa954e68> in <module>
#      15 sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
#      16 sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
# ---> 17 sns.catplot(x="[I864]RegularIncome", y="LengthOfMarriageCategorical", kind="bar", data=df)
#      18 sns.catplot(x="[I864]RegularIncome", y="DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.catplot(x="[I864]SupplementalIncome", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title='Title of Plot')
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]AgePetitioner", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[I864]NumberOfDependents", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]TotalIncome", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[I130]StayingTogetherStatus", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]AgeGapYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[I485]CriminalityProvedConvictedType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalIncome", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[I864]FederalTaxFiledYears", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[Calculated]FlagType", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[Calculated]FraudLikelihood", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriagePetitionerCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]LengthOfMarriageCategorical", kind="bar", data=df)
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df)

# %%
sns.catplot(x="[I864]RegularIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title=' IncomeCheckCategorical vs RegularIncome')
sns.catplot(x="[I864]SupplementalIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title=' IncomeCheckCategorical vs SupplementalIncome')
sns.catplot(x="[CALCULATED]AgePetitioner", y="[I864]FederalTaxFiledYears", kind="bar", data=df).set(title=' FederalTaxFiledYearsvs AgePetitioner')
sns.catplot(x="[CALCULATED]AgePetitioner", y="[CALCULATED]FederalYearsFiledCheckCategorical", kind="bar", data=df).set(title=' FederalYearsFiledCheckCategorical vs AgePetitioner')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title=' StayingTogetherStatus vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I864]FederalTaxFiledYears", kind="bar", data=df).set(title=' FederalTaxFiledYears vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[Calculated]FlagType", kind="bar", data=df).set(title=' FlagType vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[Calculated]FraudLikelihood", kind="bar", data=df).set(title='FraudLikelihood vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df).set(title='AgeGapCategorical vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title=' IncomeCheckCategorical vs AgeGapYears')
sns.catplot(x="[CALCULATED]AgeGapYears", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDateCategorical vs AgeGapYears')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title=' StayingTogetherStatus vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]AgeGapYears", kind="bar", data=df).set(title=' AgeGapYears vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df).set(title=' FederalPovertyLineValue vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalIncome", kind="bar", data=df).set(title=' TotalIncome vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[Calculated]FlagType", kind="bar", data=df).set(title=' FlagType vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[Calculated]FraudLikelihood", kind="bar", data=df).set(title=' FraudLikelihood vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df).set(title=' AgeGapCategorical vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title=' IncomeCheckCategorical vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiaryCategorical", kind="bar", data=df).set(title=' TotalYearsFromLastMarriageBeneficiaryCategorical vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDateCategorical vs NumberOfMarriagesPetitioner')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title=' StayingTogetherStatus vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]AgeGapYears", kind="bar", data=df).set(title=' AgeGapYears vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[Calculated]FlagType", kind="bar", data=df).set(title=' FlagType vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[Calculated]FraudLikelihood", kind="bar", data=df).set(title=' FraudLikelihood vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDateCategorical vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title=' IncomeCheckCategorical vs NumberOfMarriagesBeneficiary')

sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDate vs NumberOfMarriagesBeneficiary')

sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df).set(title=' FederalPovertyLineValue vs NumberOfDependents')

sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title=' TotalYearsFromLastMarriageBeneficiaryCategorical vs NumberOfDependents')

sns.catplot(x="[I864]NumberOfDependents", y="[Calculated]FraudLikelihood", kind="bar", data=df).set(title=' FraudLikelihood vs NumberOfDependents')
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDateCategorical vs NumberOfDependents')
sns.catplot(x="[CALCULATED]FederalPovertyLineValue", y="[CALCULATED]AgeGapYears", kind="bar", data=df).set(title=' AgeGapYears vs FederalPovertyLineValue')
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]TotalIncome", kind="bar", data=df).set(title='TotalIncome vs TotalIncome')
sns.catplot(x="[CALCULATED]TotalIncome", y="[CALCULATED]IncomeCheckCategorical", kind="bar", data=df).set(title='IncomeCheckCategorical vs TotalIncome')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title='IncomeCheckCategorical vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]AgeGapYears", kind="bar", data=df).set(title='AgeGapYears vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df).set(title='IncomeCheckCategorical vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df).set(title='TotalYearsFromLastMarriagePetitionerCategorical vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title='TotalYearsFromLastMarriageBeneficiaryCategorical vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[Calculated]FraudLikelihood", kind="bar", data=df).set(title='FraudLikelihood vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]AgeGapCategorical", kind="bar", data=df).set(title='AgeGapCategorical vs LengthOfMarriage')

sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title='DiffEntryDateAndMarriageDateCategorical vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title='StayingTogetherStatus vs YearsSinceDateofEntry')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df).set(title='TotalYearsFromLastMarriagePetitioner vs YearsSinceDateofEntry')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title='TotalYearsFromLastMarriageBeneficiary vs YearsSinceDateofEntry')

sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]DiffEntryDateAndMarriageDate", kind="bar", data=df).set(title='DiffEntryDateAndMarriageDate vs YearsSinceDateofEntry')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title='DiffEntryDateAndMarriageDateCategorical vs YearsSinceDateofEntry')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:392: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
sns.catplot(x="[CALCULATED]AgeGapYears", y="[I864]FederalTaxFiledYears", kind="bar", data=df).set(title=' FederalTaxFiledYears vs AgeGapYears')
sns.catplot(x="[I130]NumberOfMarriagesBeneficiary", y="[CALCULATED]DiffEntryDateAndMarriageDateCategorical", kind="bar", data=df).set(title=' DiffEntryDateAndMarriageDate vs NumberOfMarriagesBeneficiary')
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title=' TotalYearsFromLastMarriageBeneficiary vs NumberOfDependents')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df).set(title='TotalYearsFromLastMarriagePetitioner vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title='TotalYearsFromLastMarriageBeneficiary vs LengthOfMarriage')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[I130]StayingTogetherStatus", kind="bar", data=df).set(title='StayingTogetherStatus vs YearsSinceDateofEntry')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriagePetitioner", kind="bar", data=df).set(title='TotalYearsFromLastMarriagePetitioner vs YearsSinceDateofEntry')
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]TotalYearsFromLastMarriageBeneficiary", kind="bar", data=df).set(title='TotalYearsFromLastMarriageBeneficiary vs YearsSinceDateofEntry')

# %%
sns.catplot(x="[I130]NumberOfMarriagesPetitioner", y="[CALCULATED]AgeGapYears", kind="bar", data=df).set(title=' AgeGapYears vs PreviousNumberOfMarriagesPetitioner')

# %%
sns.catplot(x="[I864]NumberOfDependents", y="[CALCULATED]FederalPovertyLineValue", kind="bar", data=df).set(title=' FederalPovertyLineValue vs NumberOfDependents')

# %%
sns.set_theme(style="ticks", color_codes=True)

# %%
sns.catplot(x="[CALCULATED]LengthOfMarriage", y="[CALCULATED]AgeGapYears", kind="bar", palette="tab10",data=df).set(title='AgeGapYears vs LengthOfMarriage')

# %%
sns.catplot(x="[CALCULATED]YearsSinceDateofEntry", y="[CALCULATED]DiffEntryDateAndMarriageDate", palette="tab10", kind="bar", data=df).set(title='DiffEntryDateAndMarriageDate vs YearsSinceDateofEntry')

# %%
ax=pd.cut(df['[CALCULATED]TotalIncome'],[0,25000,50000,100000,150000]).value_counts().plot.bar(color=c)
ax.set_title("TOTAL INCOME BAR GRAPH")
ax.set_xlabel("TOTAL INCOME")
ax.set_ylabel("COUNT")
# Out:
# Text(0, 0.5, 'COUNT')
